# %%
import yfinance as yf

# %%
# 定义企业上市（股票）代码
dat = yf.Ticker("PDD")

# %%
# 简单获取近1年的日交易数据
dat.history(period="1y")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-08-09 00:00:00-04:00  138.759995  139.259995  136.949997  138.039993
# 2024-08-12 00:00:00-04:00  138.039993  143.259995  137.100006  142.470001
# 2024-08-13 00:00:00-04:00  143.929993  145.000000  142.860001  144.020004
# 2024-08-14 00:00:00-04:00  144.899994  145.000000  141.220001  141.979996
# 2024-08-15 00:00:00-04:00  144.000000  146.690002  143.570007  145.080002
# ...                               ...         ...         ...         ...
# 2025-08-04 00:00:00-04:00  111.820000  113.059998  111.440002  112.040001
# 2025-08-05 00:00:00-04:00  112.639999  114.459999  112.250000  112.620003
# 2025-08-06 00:00:00-04:00  113.650002  115.440002  112.820000  113.940002
# 2025-08-07 00:00:00-04:00  114.440002  115.849998  114.169998  114.190002
# 2025-08-08 00:00:00-04:00  114.059998  114.970001  113.129997  114.260002
#
#                             Volume  Dividends  Stock Splits
# Date
# ...

# %%
# 了解公司核心数据及概况
dat.info
# Out:
# {'address1': '25 St Stephen’s Green',
#  'address2': 'First Floor Dublin 2',
#  'city': 'Dublin',
#  'zip': 'D02 XF99',
#  'country': 'Ireland',
#  'phone': '353 1 539 7938',
#  'website': 'https://www.pddholdings.com',
#  'industry': 'Internet Retail',
#  'industryKey': 'internet-retail',
#  'industryDisp': 'Internet Retail',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %%
# 企业重要事件日历
dat.calendar
# Out:
# {'Earnings Date': [datetime.date(2025, 8, 26)],
#  'Earnings High': 18.48,
#  'Earnings Low': 9.0436,
#  'Earnings Average': 14.79894,
#  'Revenue High': 108773000000,
#  'Revenue Low': 95294231120,
#  'Revenue Average': 103195938270}

# %%
# 企业季度营收数据
dat.quarterly_income_stmt
# Out:
#                                                       2025-03-31  \
# Tax Effect Of Unusual Items                        -5.613604e+07
# Tax Rate For Calcs                                  2.318330e-01
# Normalized EBITDA                                   1.632770e+10
# Total Unusual Items                                -2.421400e+08
# Total Unusual Items Excluding Goodwill             -2.421400e+08
# Net Income From Continuing Operation Net Minori...  1.474183e+10
# Reconciled Cost Of Revenue                          4.094710e+10
# EBITDA                                              1.608556e+10
# EBIT                                                1.608556e+10
# Net Interest Income                                 2.231250e+08
# Interest Expense                                             NaN
# Interest Income                                     2.231250e+08
# Normalized Income                                   1.492783e+10
# ...

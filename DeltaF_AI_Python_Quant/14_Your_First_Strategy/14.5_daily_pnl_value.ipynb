# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import mplfinance as mpf # k线图
import warnings
warnings.filterwarnings('ignore')

# 设置中文字体显示
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']  # macos
# plt.rcParams['font.sans-serif'] = ['SimHei']  # windows
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 创建你的第一个量化策略
# 1. 参数设置：ticker 数据获取与标准化
# 2. 参数设置：captical, commission, benchmark
# 3. 策略与运行：indicators, signals
# 4. 策略与运行：cross-order, limit, pos, 涨跌停
# 5. 统计与验证：daily profit and loss, position value, total value, 日盈亏数据逐笔核对
# 6. 统计与验证：strategy statistics
# 7. 结果可视化：持仓收益、最大回撤、日盈亏
# 8. 结果可视化：市场基准（beta）对比

# %%
# 全局参数设置（或数据模块）：工商银行为例
ticker = "601398.SS"
benchmark_ticker = "000001.SS"
start_date = "2024-10-20"
end_date = "2025-10-20"

# 策略模块：全局参数
boll_period = 5
boll_k = 1.5

# %% [markdown]
# #### 参数设置：ticker 数据获取与标准化
# - 数据获取：yf.download(), 定义参数（股票代码、开始日期、结束日期、复权方式）
# - 数据清洗：nan值 -> dropna
# - 数据预览：整体看下数据

# %%
# 函数1：数据获取
def fetcher_data(ticker:str,start_date:str,end_date:str,auto_clean=True) -> pd.DataFrame:
    """ 获取数据 """
    try:
        print("正在获取历史数据：",ticker, start_date, end_date)
        data = yf.download(tickers=ticker,start=start_date,end=end_date,progress=False)
        # yfinance 个性化处理：去除第二行的列名，即ticker值
        data = data.droplevel(level=1,axis=1)
        print("完成数据获取，共有记录（条数）：", len(data))

        if auto_clean:
            clean_data(data)
    
        return data
    except Exception as e:
        print("获取数据异常：",e)
        return pd.DataFrame

# 函数2：数据清洗
def clean_data(data:pd.DataFrame) -> pd.DataFrame:
    """ 清洗数据：缺失值 """
    try:
        count_nan = data.isnull().sum().sum()
        print("当前data共有缺失值（个数）：",count_nan)
        data = data.dropna()
        count_nan = data.isnull().sum().sum()
        print("缺失值处理完毕，当前缺失值（个数）：",count_nan)
        return data
    except Exception as e:
        print("获取数据异常：",e)
        return data

# 函数3：数据预览
def preview_data(data:pd.DataFrame) -> pd.DataFrame:
    """ 按需要的格式预览数据 """
    print("数据预览：",data)

# %%
data = fetcher_data(ticker,start_date,end_date)
preview_data(data)
# Out:
# 正在获取历史数据： 601398.SS 2024-10-20 2025-10-20
# 完成数据获取，共有记录（条数）： 242
# 当前data共有缺失值（个数）： 0
# 缺失值处理完毕，当前缺失值（个数）： 0
# 数据预览： Price          Close      High       Low      Open     Volume
# Date
# 2024-10-21  5.905239  6.029863  5.886066  6.029863  568464907
# 2024-10-22  5.886066  5.953172  5.857307  5.914826  431271479
# 2024-10-23  5.886066  5.905239  5.857307  5.886066  306854479
# 2024-10-24  5.905239  5.943585  5.866893  5.876480  288789477
# 2024-10-25  5.866894  5.914826  5.847721  5.895653  284528999
# ...              ...       ...       ...       ...        ...
# 2025-10-13  7.270000  7.360000  7.230000  7.320000  395738605
# 2025-10-14  7.500000  7.500000  7.220000  7.260000  693878140
# 2025-10-15  7.460000  7.540000  7.420000  7.470000  407599319
# 2025-10-16  7.630000  7.650000  7.430000  7.430000  495623345
# 2025-10-17  7.620000  7.720000  7.570000  7.630000  408700246
#
# [242 rows x 5 columns]

# %% [markdown]
# #### 参数设置：capital, commission, slippage, benchmark
# - initial_capital：初始资金，决定能买多少股票，是收益率、仓位计算的基准，回测设置为尽可能大的整数（如100万）
# - commission: 交易手续费（佣金 + 税费），总共约为千1，即0.1% -> 0.001
# - slippage: 滑点（成交价偏差），实际成交价与理论信号价的偏差，反应市场流动性和成交延迟，回测过程中设置为万5，即0.05% -> 0.0005
# - benchmark: 市场基准（beta），使用上证指数 000001.SS

# %%
# 全局交易参数设置
trading_config = {
    "initial_capital":1000000,
    "commission":0.001, # a股买入的话是在0.0003，卖出的话 0.0007，通用使用0.001
    "slippage":0.0005
}

# %%
benchmark_data = fetcher_data(benchmark_ticker,start_date,end_date)
preview_data(benchmark_data)
# Out:
# 正在获取历史数据： 000001.SS 2024-10-20 2025-10-20
# 完成数据获取，共有记录（条数）： 242
# 当前data共有缺失值（个数）： 0
# 缺失值处理完毕，当前缺失值（个数）： 0
# 数据预览： Price             Close         High          Low         Open  Volume
# Date
# 2024-10-21  3268.110107  3300.664062  3239.096924  3276.060059  668200
# 2024-10-22  3285.866943  3294.960938  3255.137939  3263.822021  574900
# 2024-10-23  3302.802979  3331.082031  3277.065918  3285.247070  650400
# 2024-10-24  3280.262939  3292.945068  3266.882080  3287.823975  519800
# 2024-10-25  3299.699951  3319.356934  3276.129883  3280.761963  595700
# ...                 ...          ...          ...          ...     ...
# 2025-10-13  3889.501953  3895.830078  3800.104980  3800.104980  709500
# 2025-10-14  3865.229004  3918.436035  3851.121094  3910.781982  800800
# 2025-10-15  3912.208984  3912.291016  3857.666992  3867.535889  645000
# 2025-10-16  3916.228027  3931.050049  3899.166992  3900.683105  595500
# 2025-10-17  3839.754883  3921.064941  3835.364990  3912.040039  617600
#
# [242 rows x 5 columns]

# %%
# 函数4：对比投资标的与市场基准的价格曲线
def plot_compare_benchmark(ticker,benchmark_ticker,data,benchmark_data,auto_normalize=True):
    combined_data = pd.DataFrame({
        ticker: data['Close'],
        benchmark_ticker: benchmark_data['Close']
    })

    # 数据标准化（0~1）：解决价格差异太大导致无法直观对比的问题
    if auto_normalize:
        combined_data = combined_data / combined_data.iloc[0] * 100
        ylable = "相对涨幅（%）"
    else:
        ylable = "收盘价"

    combined_data.plot(figsize=(12,5), linewidth=2)
    plt.title(f"{ticker} vs {benchmark_ticker} 收盘价对比")
    plt.xlabel("日期")
    plt.ylabel(ylable)
    plt.grid(alpha=0.3)

# %%
plot_compare_benchmark(ticker,benchmark_ticker,data,benchmark_data)

# %% [markdown]
# #### 策略与运行：indicators, signals
# - 核心作用: 找到特征/因子 => 建立特征模型（单个因子/多个因子/权重配置）=> 创建策略规则 => 生成交易信号（涉及配对交易的问题）=> 进行后续回测
# - 因子概念: 基于此进行量化策略的规则编写，比如：技术指标（KDJ-动量因子、MA-趋势因子）、基本面指标（PE-价值因子）
# - 代码实现: 单因子（BOLL）=> 价格上穿下轨：买入/做多，价格下穿上轨：卖出/平仓/做空
# - 函数创建: def calculate_boll（因子指标模块）、def generate_signals（因子指标/策略模块）、def plot_signals（可视化信号-验证计算）

# %%
# 函数4：def calculate_boll（因子指标模块）
def calculate_boll(data:pd.DataFrame,period:int,std_k:int) -> pd.DataFrame:
    """ 计算Boll布林带指标
        - 中轨：n日移动均线
        - 上轨：n日移动均线 + k * n日收盘价std
        - 下轨：n日移动均线 - k * n日收盘价std
    """
    try:
        data['BOLL_MA'] = data['Close'].rolling(window=period).mean()
        data['BOLL_STD'] = data['Close'].rolling(window=period).std()
        data['BOLL_UP'] = data['BOLL_MA'] + std_k * data['BOLL_STD']
        data['BOLL_DN'] = data['BOLL_MA'] - std_k * data['BOLL_STD']
        print(f"已完成指标计算：BOLL, 周期-{period}, 标准差倍数-{std_k}")
        return data
    except Exception as e:
        print("BOLL计算异常：",e)
        return pd.DataFrame

# 函数5：def generate_signals（因子指标/策略模块）
def generate_signals(data:pd.DataFrame) -> pd.DataFrame:
    """ 通用模块：参数化设置实现多因子信号的生成，也是核心需要修改的策略规则逻辑 """
    try:
        data['Signal'] = 0
        
        # 以下内容为信号生成逻辑，可以自定义，核心是获取 Signal 列的值（1买入 -1卖出）
        
        # 单因子（BOLL）=> 价格上穿下轨：买入/做多，价格下穿上轨：卖出/平仓/做空
        prev_price = data['Close'].shift(1)
        buy_condition = (prev_price<=data['BOLL_DN']) & (data['Close']>=data['BOLL_DN'])
        sell_condition = (prev_price>=data['BOLL_UP']) & (data['Close']<=data['BOLL_UP'])

        data.loc[buy_condition,'Signal'] = 1
        data.loc[sell_condition,'Signal'] = -1
        print(f"已完成信号生成：BOLL，买入信号次数：{buy_condition.sum()}，卖出信号次数：{sell_condition.sum()}")
        return data
    except Exception as e:
        print("信号生成异常：",e)
        return pd.DataFrame
        

# 函数6：def plot_signals（可视化信号-验证计算）
def plot_signals(data:pd.DataFrame,title:str):
    """ 绘制指标与信号 """

    # 定义子图：布林带上中下轨、买入卖出信号
    buy_signal = np.where(data['Signal']==1,data['Close'],np.nan)
    sell_signal = np.where(data['Signal']==-1,data['Close'],np.nan)
    
    subplots = [
        mpf.make_addplot(data['BOLL_MA'],color='blue',linestyle='--',label='Middle'),
        mpf.make_addplot(data['BOLL_UP'],color='red',linestyle='--',label='Upper'),
        mpf.make_addplot(data['BOLL_DN'],color='green',linestyle='--',label='Lower'),
        mpf.make_addplot(buy_signal, type='scatter', marker='^', markersize=100, color='red',label='Buy'),
        mpf.make_addplot(sell_signal, type='scatter', marker='v', markersize=100, color='green',label='Sell')
    ]

    # 绘制
    mpf.plot(
        data,
        type='candle',
        style='yahoo',
        title=title,
        addplot=subplots,
        volume=False,
        figsize=(12,6),
        tight_layout=True,
        xrotation=15,
    )

# %%
indicators = calculate_boll(data,boll_period,boll_k)
signals = generate_signals(indicators)
plot_signals(signals,"Single Factor (BOLL) Signals Visualized")
# Out:
# 已完成指标计算：BOLL, 周期-5, 标准差倍数-1.5
# 已完成信号生成：BOLL，买入信号次数：3，卖出信号次数：5

# %% [markdown]
# #### 策略与运行：cross-order, limit, pos, 涨跌停
# - 核心功能：执行买卖交易、存储交易记录、每笔交易（卖出）的盈亏分析（净利润，收益率）
# - cross-order 撮合订单：买入价格 >= 卖出价格（卖盘）就会自动撮合，否则就会挂单表示委托状态中
# - 委托单类型：market 市价单 => 滑点、limit 限价单 => 无法交易 => limit price ± 0.001%
# - 处理涨跌停：前收盘价 > ± 10% 则无法成交
# - 函数：def execute_trade => 下订单+存交易记录

# %%
# 设置交易信息初始值（全局） => 思考个人账户页面的汇总数据有哪些
trading_state = {
    'cash': trading_config['initial_capital'], # 账户可用资金
    'positions': {}, # 存储投资标的持仓，如：{"000001.SS":10000, "601398.SS":2000}
    'trades': [], # 存放交易记录：price,quantity,date,cost,net_revenue,profit_rate
    'values': [] # 存放每日盈亏数据：position * price -> pos value (+cash)-> total value->今明总值比较->日盈亏
}

# %%
# 函数7：def execute_trade => 下订单+存交易记录
def execute_trade(symbol:str, quantity: int, price: float, date: pd.Timestamp, commission: float = trading_config['commission']):
    """
    执行交易：买入、卖出、交易记录；实际的交易接口交互的过程中，交易信息是直接发给券商API => 进行订单委托、更新账户信息 => 得到状态码
    """
    try:
        # 买入
        if quantity > 0:
            # 买入：执行交易 => 是否满足可交易条件：可用资金足够 => 更新持仓信息
            cost = quantity * price * (1+commission)
            if cost <= trading_state['cash']:
                trading_state['cash'] -= cost # 资金流出
                trading_state['positions'][symbol] = trading_state['positions'].get(symbol,0) + quantity # 流入
                # 买入：记录交易 => 汇总信息并添加至 trading_state['trades'] => cost 总成本
                trade_record = {
                    'symbol':symbol,
                    'quantity':quantity,
                    'price':price,
                    'type':'buy',
                    'timestamp':date,
                    'cost':cost,
                    'commission':cost - (quantity * price)
                }
                trading_state['trades'].append(trade_record)

                print(f"➕买入成功！{symbol} +{quantity}股 @{price} 总成本 {cost} 可用资金 {trading_state['cash']}")
            else:
                print(f"❌可用资金不足！总成本 {cost} 可用资金 {trading_state['cash']}")
                
        # 卖出
        else:
            quantity = abs(quantity)
            # 卖出：执行交易 => 是否满足可交易条件：仓位pos足够 => 计算收益 => 更新持仓信息
            if trading_state['positions'].get(symbol,0) >= quantity:
                # 计算净收益
                gross_revenue = quantity * price # 按当前价格和仓位卖出的市值
                commission_cost = gross_revenue * commission # 计算佣金
                net_revenue = gross_revenue - commission_cost # 纯收益

                # 找到买入成本
                buy_cost = get_latest_buy_cost(symbol)
                
                # 计算盈亏 profit and loss 盈亏
                profit_loss = net_revenue - buy_cost # 当前卖出和此前买入的收益/亏损值（差值）
                profit_rate = profit_loss / buy_cost # >0 正收益 <0 负收益
                profit_rate_pct = f"{profit_rate:.2%}"

                # 更新持仓和可用资金
                trading_state['positions'][symbol] -= quantity # 减持，资金流出
                trading_state['cash'] += net_revenue
                
                # 卖出：记录交易 => 汇总信息并添加至 trading_state['trades'] => 净收益 net_revenue, 收益比
                trade_record = {
                    'symbol':symbol,
                    'quantity':quantity,
                    'price':price,
                    'type':'sell',
                    'timestamp':date,
                    'gross_revenue':gross_revenue,
                    'commission':commission_cost,
                    'net_revenue':net_revenue,
                    'buy_cost':buy_cost,
                    'profit_loss':profit_loss,
                    'profit_rate':profit_rate,
                    'profit_rate_pct':profit_rate_pct
                }
                trading_state['trades'].append(trade_record)

                print(f"➖卖出成功！{symbol} -{quantity}股 @{price} 净收益 {net_revenue} 盈亏 {profit_loss} 盈亏比 {profit_rate_pct} 可用资金 {trading_state['cash']}")
            else:
                print(f"❌可用仓位不足！总仓位 {trading_state['positions'].get(symbol,0)}")
                
    except Exception as e:
        print(f"交易异常：{e}")

# 函数8：辅助计算函数，找到最近买入记录对应的总成本
def get_latest_buy_cost(symbol:str) -> float:
    """
    获取指定投资标的的最新买入成本（全进全出策略，即：无加减仓逻辑）
    """
    for trade in reversed(trading_state['trades']):
        if trade['symbol'] == symbol and trade['type'] == 'buy':
            return trade['cost'] 
    print(f"⚠️警告：未找到 {symbol} 的买入记录")
    return 0.0

# %%
# execute_trade(ticker, 100000, 6.78, "2025-10-31")
# execute_trade(ticker, -100000, 6.78, "2025-10-31")

# execute_trade(benchmark_ticker, 80000, 4.28, "2025-10-31")
# execute_trade(benchmark_ticker, -80000, 5.76, "2025-10-31")

# trading_state
pd.DataFrame(trading_state['trades'])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 统计与验证：daily profit and loss, position value, total value, 日盈亏数据逐笔核对
# - 每日盈亏：当日的总市值 - 昨日的总市值 => 反应你持仓标的的整体涨跌幅情况
# - 账户总市值：总市值 = 持仓市值（获取当前投资标的的股数/份额） + 账户可用资金
# - 核心功能和函数：根据交易信号执行交易（进行回测+执行策略）=> def run_strategy

# %%
# 函数9：def run_strategy
def run_strategy(signals:pd.DataFrame, symbol:str):
    """
    根据交易信号执行交易，并将计算的市值和盈亏数据进行存储
    """
    # 验证是否有 signal 列
    if 'Signal' not in signals.columns:
        raise ValueError("Data中必须包含 Signal 列")

    # 按行遍历数据 => 获取 date, price, signal => 并后续计算quantity
    for i, (date,row) in enumerate(signals.iterrows()):
        signal = row['Signal']
        price = row['Close']
        
        # 买入 - 计算按可用资金最多可以买入的股数（全仓进出 + 佣金），如果非全仓 - 可用资金的10%
        if signal == 1:
            max_quantity = int(trading_state['cash'] / ( price * (1 + trading_config['commission'])))
            if max_quantity > 0:
                execute_trade(symbol, max_quantity, price, date)
        # 卖出
        elif signal == -1:
            current_quantity = trading_state['positions'].get(symbol,0)
            if current_quantity > 0:
                execute_trade(symbol, -current_quantity, price, date)

        # 计算市值：持仓、账户总值
        position_value = trading_state['positions'].get(symbol,0) * price
        total_value = position_value + trading_state['cash']

        # 计算盈亏：当日 - 昨日总值
        if i == 0:
            daily_pnl = 0
        else:
            previous_value = trading_state['values'][-1]['total_value']
            daily_pnl = total_value - previous_value # 昨日市值

        # 存储数据
        daily_record = {
            'date':date,
            'signal':signal,
            'price':price,
            'cash':trading_state['cash'],
            'position':trading_state['positions'].get(symbol,0),
            'position_value':position_value,
            'total_value':total_value,
            'daily_pnl':daily_pnl
        }

        trading_state['values'].append(daily_record)

        # 打印数据
        print(f"📅{date.strftime('%Y-%m-%d')} 信号{signal} 价格{price:.2f} 仓位{trading_state['positions'].get(symbol,0)} 仓位市值{position_value:.2f} 可用资金{trading_state['cash']:.2f} 总市值{total_value:.2f} 日盈亏{daily_pnl:.2f}")

        # 存储csv -> 函数外实现，便于核对数据

# %%
run_strategy(signals,ticker)
# Out:
# 📅2024-10-21 信号0.0 价格5.91 仓位0 仓位市值0.00 可用资金1000000.00 总市值1000000.00 日盈亏0.00
# 📅2024-10-22 信号0.0 价格5.89 仓位0 仓位市值0.00 可用资金1000000.00 总市值1000000.00 日盈亏0.00
# 📅2024-10-23 信号0.0 价格5.89 仓位0 仓位市值0.00 可用资金1000000.00 总市值1000000.00 日盈亏0.00
# 📅2024-10-24 信号0.0 价格5.91 仓位0 仓位市值0.00 可用资金1000000.00 总市值1000000.00 日盈亏0.00
# 📅2024-10-25 信号0.0 价格5.87 仓位0 仓位市值0.00 可用资金1000000.00 总市值1000000.00 日盈亏0.00
# 📅2024-10-28 信号0.0 价格5.82 仓位0 仓位市值0.00 可用资金1000000.00 总市值1000000.00 日盈亏0.00
# 📅2024-10-29 信号0.0 价格5.81 仓位0 仓位市值0.00 可用资金1000000.00 总市值1000000.00 日盈亏0.00
# 📅2024-10-30 信号0.0 价格5.76 仓位0 仓位市值0.00 可用资金1000000.00 总市值1000000.00 日盈亏0.00
# 📅2024-10-31 信号0.0 价格5.79 仓位0 仓位市值0.00 可用资金1000000.00 总市值1000000.00 日盈亏0.00
# 📅2024-11-01 信号0.0 价格5.90 仓位0 仓位市值0.00 可用资金1000000.00 总市值1000000.00 日盈亏0.00
# 📅2024-11-04 信号0.0 价格5.88 仓位0 仓位市值0.00 可用资金1000000.00 总市值1000000.00 日盈亏0.00
# 📅2024-11-05 信号0.0 价格5.90 仓位0 仓位市值0.00 可用资金1000000.00 总市值1000000.00 日盈亏0.00
# 📅2024-11-06 信号0.0 价格5.84 仓位0 仓位市值0.00 可用资金1000000.00 总市值1000000.00 日盈亏0.00
# ➕买入成功！601398.SS +169447股 @5.895653247833252 总成本 999999.7566414865 可用资金 0.2433585134567693
# 📅2024-11-07 信号1.0 价格5.90 仓位169447 仓位市值999000.76 可用资金0.24 总市值999001.00 日盈亏-999.00
# 📅2024-11-08 信号0.0 价格5.86 仓位169447 仓位市值992503.17 可用资金0.24 总市值992503.42 日盈亏-6497.58
# 📅2024-11-11 信号0.0 价格5.79 仓位169447 仓位市值981132.46 可用资金0.24 总市值981132.71 日盈亏-11370.71
# 📅2024-11-12 信号0.0 价格5.75 仓位169447 仓位市值974634.88 可用资金0.24 总市值974635.12 日盈亏-6497.58
# 📅2024-11-13 信号0.0 价格5.79 仓位169447 仓位市值981132.46 可用资金0.24 总市值981132.71 日盈亏6497.58
# 📅2024-11-14 信号0.0 价格5.82 仓位169447 仓位市值986005.67 可用资金0.24 总市值986005.91 日盈亏4873.21
# 📅2024-11-15 信号0.0 价格5.80 仓位169447 仓位市值982756.84 可用资金0.24 总市值982757.08 日盈亏-3248.83
# 📅2024-11-18 信号0.0 价格5.93 仓位169447 仓位市值1005498.34 可用资金0.24 总市值1005498.58 日盈亏22741.50
# 📅2024-11-19 信号0.0 价格5.90 仓位169447 仓位市值999000.76 可用资金0.24 总市值999001.00 日盈亏-6497.58
# 📅2024-11-20 信号0.0 价格5.89 仓位169447 仓位市值997376.30 可用资金0.24 总市值997376.54 日盈亏-1624.46
# 📅2024-11-21 信号0.0 价格5.88 仓位169447 仓位市值995752.00 可用资金0.24 总市值995752.25 日盈亏-1624.29
# 📅2024-11-22 信号0.0 价格5.80 仓位169447 仓位市值982756.84 可用资金0.24 总市值982757.08 日盈亏-12995.17
# 📅2024-11-25 信号0.0 价格5.82 仓位169447 仓位市值986005.67 可用资金0.24 总市值986005.91 日盈亏3248.83
# 📅2024-11-26 信号0.0 价格5.91 仓位169447 仓位市值1000625.05 可用资金0.24 总市值1000625.29 日盈亏14619.38
# 📅2024-11-27 信号0.0 价格5.94 仓位169447 仓位市值1007122.63 可用资金0.24 总市值1007122.88 日盈亏6497.58
# 📅2024-11-28 信号0.0 价格5.93 仓位169447 仓位市值1005498.34 可用资金0.24 总市值1005498.58 日盈亏-1624.29
# 📅2024-11-29 信号0.0 价格5.90 仓位169447 仓位市值999000.76 可用资金0.24 总市值999001.00 日盈亏-6497.58
# 📅2024-12-02 信号0.0 价格5.88 仓位169447 仓位市值995752.00 可用资金0.24 总市值995752.25 日盈亏-3248.75
# 📅2024-12-03 信号0.0 价格5.95 仓位169447 仓位市值1008747.09 可用资金0.24 总市值1008747.33 日盈亏12995.09
# 📅2024-12-04 信号0.0 价格6.00 仓位169447 仓位市值1016869.13 可用资金0.24 总市值1016869.37 日盈亏8122.04
# 📅2024-12-05 信号0.0 价格6.00 仓位169447 仓位市值1016869.13 可用资金0.24 总市值1016869.37 日盈亏0.00
# 📅2024-12-06 信号0.0 价格6.06 仓位169447 仓位市值1026615.46 可用资金0.24 总市值1026615.71 日盈亏9746.33
# 📅2024-12-09 信号0.0 价格6.06 仓位169447 仓位市值1026615.46 可用资金0.24 总市值1026615.71 日盈亏0.00
# 📅2024-12-10 信号0.0 价格6.15 仓位169447 仓位市值1042859.38 可用资金0.24 总市值1042859.62 日盈亏16243.92
# ➖卖出成功！601398.SS -169447股 @6.049036026000977 净收益 1023966.0164902897 盈亏 23966.259848803165 盈亏比 2.40% 可用资金 1023966.2598488032
# 📅2024-12-11 信号-1.0 价格6.05 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏-18893.36
# 📅2024-12-12 信号0.0 价格6.15 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2024-12-13 信号0.0 价格6.13 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2024-12-16 信号0.0 价格6.26 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2024-12-17 信号0.0 价格6.24 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2024-12-18 信号0.0 价格6.32 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2024-12-19 信号0.0 价格6.22 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2024-12-20 信号0.0 价格6.26 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2024-12-23 信号0.0 价格6.42 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2024-12-24 信号0.0 价格6.50 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2024-12-25 信号0.0 价格6.65 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2024-12-26 信号0.0 价格6.64 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2024-12-27 信号0.0 价格6.63 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2024-12-30 信号0.0 价格6.66 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2024-12-31 信号0.0 价格6.63 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2025-01-02 信号0.0 价格6.52 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2025-01-03 信号0.0 价格6.43 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2025-01-06 信号0.0 价格6.47 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2025-01-07 信号0.0 价格6.55 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2025-01-08 信号0.0 价格6.62 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2025-01-09 信号0.0 价格6.57 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2025-01-10 信号0.0 价格6.53 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2025-01-13 信号0.0 价格6.46 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2025-01-14 信号0.0 价格6.47 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2025-01-15 信号0.0 价格6.49 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2025-01-16 信号0.0 价格6.54 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2025-01-17 信号-1.0 价格6.47 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2025-01-20 信号0.0 价格6.43 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2025-01-21 信号0.0 价格6.42 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# 📅2025-01-22 信号0.0 价格6.31 仓位0 仓位市值0.00 可用资金1023966.26 总市值1023966.26 日盈亏0.00
# ➕买入成功！601398.SS +156817股 @6.523141384124756 总成本 1023962.401896726 可用资金 3.8579520771745592
# 📅2025-01-23 信号1.0 价格6.52 仓位156817 仓位市值1022939.46 可用资金3.86 总市值1022943.32 日盈亏-1022.94
# 📅2025-01-24 信号0.0 价格6.53 仓位156817 仓位市值1024475.44 可用资金3.86 总市值1024479.30 日盈亏1535.98
# 📅2025-01-27 信号0.0 价格6.68 仓位156817 仓位市值1047514.65 可用资金3.86 总市值1047518.51 日盈亏23039.21
# 📅2025-02-05 信号0.0 价格6.55 仓位156817 仓位市值1027547.32 可用资金3.86 总市值1027551.18 日盈亏-19967.33
# 📅2025-02-06 信号0.0 价格6.55 仓位156817 仓位市值1027547.32 可用资金3.86 总市值1027551.18 日盈亏0.00
# 📅2025-02-07 信号0.0 价格6.55 仓位156817 仓位市值1027547.32 可用资金3.86 总市值1027551.18 日盈亏0.00
# 📅2025-02-10 信号0.0 价格6.53 仓位156817 仓位市值1024475.44 可用资金3.86 总市值1024479.30 日盈亏-3071.88
# 📅2025-02-11 信号0.0 价格6.68 仓位156817 仓位市值1047514.65 可用资金3.86 总市值1047518.51 日盈亏23039.21
# 📅2025-02-12 信号0.0 价格6.76 仓位156817 仓位市值1059802.17 可用资金3.86 总市值1059806.03 日盈亏12287.52
# 📅2025-02-13 信号0.0 价格6.82 仓位156817 仓位市值1069017.89 可用资金3.86 总市值1069021.74 日盈亏9215.71
# 📅2025-02-14 信号0.0 价格6.85 仓位156817 仓位市值1073625.67 可用资金3.86 总市值1073629.53 日盈亏4607.78
# 📅2025-02-17 信号0.0 价格6.82 仓位156817 仓位市值1069017.89 可用资金3.86 总市值1069021.74 日盈亏-4607.78
# 📅2025-02-18 信号0.0 价格6.94 仓位156817 仓位市值1088985.14 可用资金3.86 总市值1088989.00 日盈亏19967.26
# 📅2025-02-19 信号0.0 价格6.91 仓位156817 仓位市值1082841.38 可用资金3.86 总市值1082845.24 日盈亏-6143.76
# 📅2025-02-20 信号0.0 价格6.93 仓位156817 仓位市值1087449.17 可用资金3.86 总市值1087453.02 日盈亏4607.78
# 📅2025-02-21 信号0.0 价格6.79 仓位156817 仓位市值1064410.03 可用资金3.86 总市值1064413.89 日盈亏-23039.14
# 📅2025-02-24 信号0.0 价格6.75 仓位156817 仓位市值1058266.19 可用资金3.86 总市值1058270.05 日盈亏-6143.83
# 📅2025-02-25 信号0.0 价格6.72 仓位156817 仓位市值1053658.41 可用资金3.86 总市值1053662.27 日盈亏-4607.78
# 📅2025-02-26 信号0.0 价格6.74 仓位156817 仓位市值1056730.29 可用资金3.86 总市值1056734.15 日盈亏3071.88
# 📅2025-02-27 信号0.0 价格6.79 仓位156817 仓位市值1064410.03 可用资金3.86 总市值1064413.89 日盈亏7679.74
# ➖卖出成功！601398.SS -156817股 @6.72882604598999 净收益 1054139.1197399583 盈亏 30176.717843232327 盈亏比 2.95% 可用资金 1054142.9776920355
# 📅2025-02-28 信号-1.0 价格6.73 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏-10270.91
# 📅2025-03-03 信号0.0 价格6.71 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-04 信号0.0 价格6.64 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-05 信号0.0 价格6.73 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-06 信号0.0 价格6.69 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-07 信号0.0 价格6.66 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-10 信号0.0 价格6.60 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-11 信号0.0 价格6.64 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-12 信号0.0 价格6.58 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-13 信号0.0 价格6.59 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-14 信号0.0 价格6.61 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-17 信号0.0 价格6.67 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-18 信号0.0 价格6.66 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-19 信号0.0 价格6.73 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-20 信号0.0 价格6.70 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-21 信号0.0 价格6.62 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-24 信号0.0 价格6.68 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-25 信号0.0 价格6.71 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-26 信号0.0 价格6.69 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-27 信号0.0 价格6.73 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-28 信号0.0 价格6.74 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-03-31 信号0.0 价格6.75 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# 📅2025-04-01 信号0.0 价格6.66 仓位0 仓位市值0.00 可用资金1054142.98 总市值1054142.98 日盈亏0.00
# ➕买入成功！601398.SS +156961股 @6.709237098693848 总成本 1054141.652812333 可用资金 1.3248797024134547
# 📅2025-04-02 信号1.0 价格6.71 仓位156961 仓位市值1053088.56 可用资金1.32 总市值1053089.89 日盈亏-1053.09
# 📅2025-04-03 信号0.0 价格6.75 仓位156961 仓位市值1059237.97 可用资金1.32 总市值1059239.29 日盈亏6149.40
# 📅2025-04-07 信号0.0 价格6.62 仓位156961 仓位市值1039252.45 可用资金1.32 总市值1039253.77 日盈亏-19985.52
# 📅2025-04-08 信号0.0 价格6.68 仓位156961 仓位市值1048476.55 可用资金1.32 总市值1048477.88 日盈亏9224.10
# 📅2025-04-09 信号0.0 价格6.66 仓位156961 仓位市值1045401.85 可用资金1.32 总市值1045403.17 日盈亏-3074.70
# 📅2025-04-10 信号0.0 价格6.61 仓位156961 仓位市值1037715.06 可用资金1.32 总市值1037716.39 日盈亏-7686.79
# 📅2025-04-11 信号0.0 价格6.66 仓位156961 仓位市值1045401.85 可用资金1.32 总市值1045403.17 日盈亏7686.79
# 📅2025-04-14 信号0.0 价格6.73 仓位156961 仓位市值1056163.27 可用资金1.32 总市值1056164.59 日盈亏10761.42
# 📅2025-04-15 信号0.0 价格6.82 仓位156961 仓位市值1069999.53 可用资金1.32 总市值1070000.86 日盈亏13836.27
# 📅2025-04-16 信号0.0 价格6.91 仓位156961 仓位市值1085373.03 可用资金1.32 总市值1085374.36 日盈亏15373.50
# 📅2025-04-17 信号0.0 价格6.91 仓位156961 仓位市值1083835.72 可用资金1.32 总市值1083837.05 日盈亏-1537.31
# 📅2025-04-18 信号0.0 价格6.99 仓位156961 仓位市值1097671.91 可用资金1.32 总市值1097673.24 日盈亏13836.19
# 📅2025-04-21 信号0.0 价格6.91 仓位156961 仓位市值1083835.72 可用资金1.32 总市值1083837.05 日盈亏-13836.19
# 📅2025-04-22 信号0.0 价格7.00 仓位156961 仓位市值1099209.30 可用资金1.32 总市值1099210.63 日盈亏15373.58
# 📅2025-04-23 信号0.0 价格6.96 仓位156961 仓位市值1093059.90 可用资金1.32 总市值1093061.22 日盈亏-6149.40
# 📅2025-04-24 信号0.0 价格7.09 仓位156961 仓位市值1113045.42 可用资金1.32 总市值1113046.74 日盈亏19985.52
# 📅2025-04-25 信号0.0 价格7.06 仓位156961 仓位市值1108433.40 可用资金1.32 总市值1108434.73 日盈亏-4612.01
# 📅2025-04-28 信号0.0 价格7.14 仓位156961 仓位市值1120732.21 可用资金1.32 总市值1120733.53 日盈亏12298.80
# 📅2025-04-29 信号0.0 价格7.12 仓位156961 仓位市值1117657.50 可用资金1.32 总市值1117658.83 日盈亏-3074.70
# 📅2025-04-30 信号0.0 价格6.87 仓位156961 仓位市值1077686.32 可用资金1.32 总市值1077687.64 日盈亏-39971.18
# 📅2025-05-06 信号0.0 价格6.84 仓位156961 仓位市值1073074.23 可用资金1.32 总市值1073075.56 日盈亏-4612.09
# 📅2025-05-07 信号0.0 价格6.96 仓位156961 仓位市值1093059.90 可用资金1.32 总市值1093061.22 日盈亏19985.67
# 📅2025-05-08 信号0.0 价格6.96 仓位156961 仓位市值1093059.90 可用资金1.32 总市值1093061.22 日盈亏0.00
# 📅2025-05-09 信号0.0 价格7.02 仓位156961 仓位市值1102284.00 可用资金1.32 总市值1102285.33 日盈亏9224.10
# 📅2025-05-12 信号0.0 价格7.01 仓位156961 仓位市值1100746.61 可用资金1.32 总市值1100747.94 日盈亏-1537.39
# 📅2025-05-13 信号0.0 价格7.08 仓位156961 仓位市值1111508.10 可用资金1.32 总市值1111509.43 日盈亏10761.49
# 📅2025-05-14 信号0.0 价格7.08 仓位156961 仓位市值1111508.10 可用资金1.32 总市值1111509.43 日盈亏0.00
# 📅2025-05-15 信号0.0 价格7.12 仓位156961 仓位市值1117657.50 可用资金1.32 总市值1117658.83 日盈亏6149.40
# 📅2025-05-16 信号0.0 价格7.01 仓位156961 仓位市值1100746.61 可用资金1.32 总市值1100747.94 日盈亏-16910.89
# 📅2025-05-19 信号0.0 价格6.97 仓位156961 仓位市值1094597.21 可用资金1.32 总市值1094598.54 日盈亏-6149.40
# 📅2025-05-20 信号0.0 价格6.98 仓位156961 仓位市值1096134.60 可用资金1.32 总市值1096135.92 日盈亏1537.39
# 📅2025-05-21 信号0.0 价格6.99 仓位156961 仓位市值1097671.91 可用资金1.32 总市值1097673.24 日盈亏1537.31
# 📅2025-05-22 信号0.0 价格6.97 仓位156961 仓位市值1094597.21 可用资金1.32 总市值1094598.54 日盈亏-3074.70
# 📅2025-05-23 信号0.0 价格6.93 仓位156961 仓位市值1088447.74 可用资金1.32 总市值1088449.06 日盈亏-6149.48
# 📅2025-05-26 信号0.0 价格6.91 仓位156961 仓位市值1083835.72 可用资金1.32 总市值1083837.05 日盈亏-4612.01
# 📅2025-05-27 信号0.0 价格6.91 仓位156961 仓位市值1085373.03 可用资金1.32 总市值1085374.36 日盈亏1537.31
# 📅2025-05-28 信号0.0 价格6.91 仓位156961 仓位市值1083835.72 可用资金1.32 总市值1083837.05 日盈亏-1537.31
# 📅2025-05-29 信号0.0 价格6.90 仓位156961 仓位市值1082298.33 可用资金1.32 总市值1082299.66 日盈亏-1537.39
# 📅2025-05-30 信号0.0 价格6.92 仓位156961 仓位市值1086910.42 可用资金1.32 总市值1086911.75 日盈亏4612.09
# 📅2025-06-03 信号0.0 价格6.96 仓位156961 仓位市值1093059.90 可用资金1.32 总市值1093061.22 日盈亏6149.48
# 📅2025-06-04 信号0.0 价格6.93 仓位156961 仓位市值1088447.74 可用资金1.32 总市值1088449.06 日盈亏-4612.16
# 📅2025-06-05 信号0.0 价格6.94 仓位156961 仓位市值1089985.12 可用资金1.32 总市值1089986.45 日盈亏1537.39
# 📅2025-06-06 信号0.0 价格6.95 仓位156961 仓位市值1091522.51 可用资金1.32 总市值1091523.84 日盈亏1537.39
# 📅2025-06-09 信号0.0 价格6.93 仓位156961 仓位市值1088447.74 可用资金1.32 总市值1088449.06 日盈亏-3074.78
# 📅2025-06-10 信号0.0 价格6.95 仓位156961 仓位市值1091522.51 可用资金1.32 总市值1091523.84 日盈亏3074.78
# 📅2025-06-11 信号0.0 价格6.97 仓位156961 仓位市值1094597.21 可用资金1.32 总市值1094598.54 日盈亏3074.70
# 📅2025-06-12 信号0.0 价格6.96 仓位156961 仓位市值1093059.90 可用资金1.32 总市值1093061.22 日盈亏-1537.31
# 📅2025-06-13 信号0.0 价格6.94 仓位156961 仓位市值1089985.12 可用资金1.32 总市值1089986.45 日盈亏-3074.78
# 📅2025-06-16 信号0.0 价格6.99 仓位156961 仓位市值1097671.91 可用资金1.32 总市值1097673.24 日盈亏7686.79
# 📅2025-06-17 信号0.0 价格7.02 仓位156961 仓位市值1102284.00 可用资金1.32 总市值1102285.33 日盈亏4612.09
# 📅2025-06-18 信号0.0 价格7.10 仓位156961 仓位市值1114582.80 可用资金1.32 总市值1114584.13 日盈亏12298.80
# 📅2025-06-19 信号0.0 价格7.15 仓位156961 仓位市值1122269.59 可用资金1.32 总市值1122270.92 日盈亏7686.79
# 📅2025-06-20 信号0.0 价格7.22 仓位156961 仓位市值1133031.08 可用资金1.32 总市值1133032.41 日盈亏10761.49
# 📅2025-06-23 信号0.0 价格7.37 仓位156961 仓位市值1156091.45 可用资金1.32 总市值1156092.78 日盈亏23060.37
# 📅2025-06-24 信号0.0 价格7.47 仓位156961 仓位市值1173002.34 可用资金1.32 总市值1173003.67 日盈亏16910.89
# 📅2025-06-25 信号0.0 价格7.51 仓位156961 仓位市值1179151.74 可用资金1.32 总市值1179153.07 日盈亏6149.40
# 📅2025-06-26 信号0.0 价格7.56 仓位156961 仓位市值1186838.53 可用资金1.32 总市值1186839.86 日盈亏7686.79
# 📅2025-06-27 信号0.0 价格7.35 仓位156961 仓位市值1153016.75 可用资金1.32 总市值1153018.08 日盈亏-33821.78
# 📅2025-06-30 信号0.0 价格7.43 仓位156961 仓位市值1166852.94 可用资金1.32 总市值1166854.27 日盈亏13836.19
# 📅2025-07-01 信号0.0 价格7.50 仓位156961 仓位市值1177614.36 可用资金1.32 总市值1177615.68 日盈亏10761.42
# 📅2025-07-02 信号0.0 价格7.52 仓位156961 仓位市值1180689.06 可用资金1.32 总市值1180690.38 日盈亏3074.70
# 📅2025-07-03 信号0.0 价格7.48 仓位156961 仓位市值1174539.66 可用资金1.32 总市值1174540.98 日盈亏-6149.40
# 📅2025-07-04 信号0.0 价格7.59 仓位156961 仓位市值1191450.62 可用资金1.32 总市值1191451.95 日盈亏16910.97
# 📅2025-07-07 信号0.0 价格7.57 仓位156961 仓位市值1188375.92 可用资金1.32 总市值1188377.25 日盈亏-3074.70
# 📅2025-07-08 信号0.0 价格7.60 仓位156961 仓位市值1192988.01 可用资金1.32 总市值1192989.33 日盈亏4612.09
# 📅2025-07-09 信号0.0 价格7.69 仓位156961 仓位市值1206824.13 可用资金1.32 总市值1206825.45 日盈亏13836.12
# 📅2025-07-10 信号0.0 价格7.91 仓位156961 仓位市值1242183.30 可用资金1.32 总市值1242184.62 日盈亏35359.17
# 📅2025-07-11 信号0.0 价格7.85 仓位156961 仓位市值1231421.88 可用资金1.32 总市值1231423.21 日盈亏-10761.42
# 📅2025-07-14 信号0.0 价格7.84 仓位156961 仓位市值1230574.26 可用资金1.32 总市值1230575.59 日盈亏-847.62
# 📅2025-07-15 信号0.0 价格7.80 仓位156961 仓位市值1224295.83 可用资金1.32 总市值1224297.15 日盈亏-6278.43
# 📅2025-07-16 信号0.0 价格7.80 仓位156961 仓位市值1224295.83 可用资金1.32 总市值1224297.15 日盈亏0.00
# 📅2025-07-17 信号0.0 价格7.75 仓位156961 仓位市值1216447.75 可用资金1.32 总市值1216449.07 日盈亏-7848.08
# 📅2025-07-18 信号0.0 价格7.77 仓位156961 仓位市值1219586.97 可用资金1.32 总市值1219588.29 日盈亏3139.22
# 📅2025-07-21 信号0.0 价格7.70 仓位156961 仓位市值1208599.67 可用资金1.32 总市值1208600.99 日盈亏-10987.30
# 📅2025-07-22 信号0.0 价格7.60 仓位156961 仓位市值1192903.59 可用资金1.32 总市值1192904.91 日盈亏-15696.09
# 📅2025-07-23 信号0.0 价格7.65 仓位156961 仓位市值1200751.66 可用资金1.32 总市值1200752.99 日盈亏7848.08
# 📅2025-07-24 信号0.0 价格7.55 仓位156961 仓位市值1185055.58 可用资金1.32 总市值1185056.90 日盈亏-15696.09
# 📅2025-07-25 信号0.0 价格7.49 仓位156961 仓位市值1175637.85 可用资金1.32 总市值1175639.18 日盈亏-9417.73
# 📅2025-07-28 信号0.0 价格7.49 仓位156961 仓位市值1175637.85 可用资金1.32 总市值1175639.18 日盈亏0.00
# 📅2025-07-29 信号0.0 价格7.43 仓位156961 仓位市值1166220.20 可用资金1.32 总市值1166221.53 日盈亏-9417.65
# 📅2025-07-30 信号0.0 价格7.49 仓位156961 仓位市值1175637.85 可用资金1.32 总市值1175639.18 日盈亏9417.65
# 📅2025-07-31 信号0.0 价格7.56 仓位156961 仓位市值1186625.15 可用资金1.32 总市值1186626.48 日盈亏10987.30
# 📅2025-08-01 信号0.0 价格7.62 仓位156961 仓位市值1196042.80 可用资金1.32 总市值1196044.13 日盈亏9417.65
# 📅2025-08-04 信号0.0 价格7.68 仓位156961 仓位市值1205460.45 可用资金1.32 总市值1205461.78 日盈亏9417.65
# 📅2025-08-05 信号0.0 价格7.76 仓位156961 仓位市值1218017.40 可用资金1.32 总市值1218018.72 日盈亏12556.94
# 📅2025-08-06 信号0.0 价格7.76 仓位156961 仓位市值1218017.40 可用资金1.32 总市值1218018.72 日盈亏0.00
# 📅2025-08-07 信号0.0 价格7.84 仓位156961 仓位市值1230574.26 可用资金1.32 总市值1230575.59 日盈亏12556.87
# 📅2025-08-08 信号0.0 价格7.79 仓位156961 仓位市值1222726.18 可用资金1.32 总市值1222727.51 日盈亏-7848.08
# 📅2025-08-11 信号0.0 价格7.70 仓位156961 仓位市值1208599.67 可用资金1.32 总市值1208600.99 日盈亏-14126.51
# 📅2025-08-12 信号0.0 价格7.78 仓位156961 仓位市值1221156.61 可用资金1.32 总市值1221157.94 日盈亏12556.94
# 📅2025-08-13 信号0.0 价格7.70 仓位156961 仓位市值1208599.67 可用资金1.32 总市值1208600.99 日盈亏-12556.94
# 📅2025-08-14 信号0.0 价格7.69 仓位156961 仓位市值1207030.10 可用资金1.32 总市值1207031.42 日盈亏-1569.57
# 📅2025-08-15 信号0.0 价格7.55 仓位156961 仓位市值1185055.58 可用资金1.32 总市值1185056.90 日盈亏-21974.52
# 📅2025-08-18 信号0.0 价格7.53 仓位156961 仓位市值1181916.36 可用资金1.32 总市值1181917.69 日盈亏-3139.22
# 📅2025-08-19 信号0.0 价格7.57 仓位156961 仓位市值1188194.80 可用资金1.32 总市值1188196.12 日盈亏6278.43
# 📅2025-08-20 信号0.0 价格7.57 仓位156961 仓位市值1188194.80 可用资金1.32 总市值1188196.12 日盈亏0.00
# 📅2025-08-21 信号0.0 价格7.60 仓位156961 仓位市值1192903.59 可用资金1.32 总市值1192904.91 日盈亏4708.79
# 📅2025-08-22 信号0.0 价格7.63 仓位156961 仓位市值1197612.45 可用资金1.32 总市值1197613.77 日盈亏4708.86
# ➖卖出成功！601398.SS -156961股 @7.590000152587891 净收益 1190142.6799363976 盈亏 136001.0271240645 盈亏比 12.90% 可用资金 1190144.0048161
# 📅2025-08-25 信号-1.0 价格7.59 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏-7469.77
# 📅2025-08-26 信号0.0 价格7.55 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-08-27 信号0.0 价格7.41 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-08-28 信号0.0 价格7.38 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-08-29 信号0.0 价格7.43 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-01 信号0.0 价格7.38 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-02 信号0.0 价格7.57 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-03 信号-1.0 价格7.44 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-04 信号0.0 价格7.54 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-05 信号0.0 价格7.44 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-08 信号0.0 价格7.40 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-09 信号0.0 价格7.43 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-10 信号0.0 价格7.47 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-11 信号0.0 价格7.51 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-12 信号0.0 价格7.48 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-15 信号0.0 价格7.43 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-16 信号0.0 价格7.45 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-17 信号0.0 价格7.46 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-18 信号0.0 价格7.29 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-19 信号0.0 价格7.20 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-22 信号0.0 价格7.18 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-23 信号0.0 价格7.40 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-24 信号0.0 价格7.47 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-25 信号0.0 价格7.38 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-26 信号0.0 价格7.41 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-29 信号0.0 价格7.33 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-09-30 信号0.0 价格7.30 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-10-09 信号0.0 价格7.31 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-10-10 信号0.0 价格7.31 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-10-13 信号0.0 价格7.27 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-10-14 信号0.0 价格7.50 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-10-15 信号0.0 价格7.46 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-10-16 信号0.0 价格7.63 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00
# 📅2025-10-17 信号0.0 价格7.62 仓位0 仓位市值0.00 可用资金1190144.00 总市值1190144.00 日盈亏0.00

# %%
pd.DataFrame(trading_state['values']).to_csv('daily_pnl_records.csv',index=False)
pd.DataFrame(trading_state['trades']).to_csv('trade_records.csv',index=False)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# 1. 准备训练、预测数据集

# %%
df = pd.read_csv("stock_data.csv",index_col="Date",usecols=["Date","Close"])[-1000:]
df
# Out:
#                 Close
# Date
# 2021/6/29  133.415100
# 2021/6/30  134.031647
# 2021/7/1   134.335022
# 2021/7/2   136.967514
# 2021/7/6   138.983459
# ...               ...
# 2025/6/16  198.419998
# 2025/6/17  195.639999
# 2025/6/18  196.580002
# 2025/6/20  201.000000
# 2025/6/23  201.500000
#
# [1000 rows x 1 columns]

# %%
X = df[:-1]
y = df[1:]
X,y
# Out:
# (                Close
#  Date
#  2021/6/29  133.415100
#  2021/6/30  134.031647
#  2021/7/1   134.335022
#  2021/7/2   136.967514
#  2021/7/6   138.983459
#  ...               ...
#  2025/6/13  196.449997
#  2025/6/16  198.419998
#  2025/6/17  195.639999
#  2025/6/18  196.580002
#  2025/6/20  201.000000
#
#  [999 rows x 1 columns],
#                  Close
#  Date
#  2021/6/30  134.031647
#  2021/7/1   134.335022
#  2021/7/2   136.967514
#  2021/7/6   138.983459
#  2021/7/7   141.478973
#  ...               ...
#  2025/6/16  198.419998
#  2025/6/17  195.639999
#  2025/6/18  196.580002
#  2025/6/20  201.000000
#  2025/6/23  201.500000
#
#  [999 rows x 1 columns])

# %%
# 2. 创建并训练模型

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
# 3. 得到参数与公式：y=ax+b

# %%
model.coef_,model.intercept_
# Out:
# (array([[0.99425875]]), array([1.0885317]))

# %% [raw]
# y = 0.99425875 * x + 1.0885317

# %%
# 4. 预测次日收盘价

# %%
model.predict([[222]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[221.81397447]])

# %%
0.99425875 * 222 + 1.0885317
# Out:
# 221.8139742

# %%
# 5. 绘制数据集与线性模型

# %%
plt.scatter(X,y)
plt.plot(X,model.predict(X),color="red",label="regression line")

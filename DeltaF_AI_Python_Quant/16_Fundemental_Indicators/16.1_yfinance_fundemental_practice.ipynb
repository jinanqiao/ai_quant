# %%
import yfinance as yf

# %%
t = yf.Ticker("GOOG")

# %%
t.income_stmt
# Out:
#                                                       2024-12-31  \
# Tax Effect Of Unusual Items                         3.401360e+08
# Tax Rate For Calcs                                  1.640000e-01
# Normalized EBITDA                                   1.333200e+11
# Total Unusual Items                                 2.074000e+09
# Total Unusual Items Excluding Goodwill              2.074000e+09
# Net Income From Continuing Operation Net Minori...  1.001180e+11
# Reconciled Depreciation                             1.531100e+10
# Reconciled Cost Of Revenue                          1.463060e+11
# EBITDA                                              1.353940e+11
# EBIT                                                1.200830e+11
# Net Interest Income                                 4.214000e+09
# Interest Expense                                    2.680000e+08
# Interest Income                                     4.482000e+09
# ...

# %%
t.balance_sheet
# Out:
#                                                     2024-12-31    2023-12-31  \
# Treasury Shares Number                                     NaN  0.000000e+00
# Ordinary Shares Number                            1.221100e+10  1.246000e+10
# Share Issued                                      1.221100e+10  1.246000e+10
# Total Debt                                        2.546100e+10  2.712100e+10
# Tangible Book Value                               2.931990e+11  2.541810e+11
# ...                                                        ...           ...
# Allowance For Doubtful Accounts Receivable       -8.790000e+08 -7.710000e+08
# Gross Accounts Receivable                         5.321900e+10  4.873500e+10
# Cash Cash Equivalents And Short Term Investments  9.565700e+10  1.109160e+11
# Other Short Term Investments                      7.219100e+10  8.686800e+10
# Cash And Cash Equivalents                         2.346600e+10  2.404800e+10
#
# ...

# %%
t.cash_flow
# Out:
#                                                   2024-12-31    2023-12-31  \
# Free Cash Flow                                  7.276400e+10  6.949500e+10
# Repurchase Of Capital Stock                    -6.222200e+10 -6.150400e+10
# Repayment Of Debt                              -1.270100e+10 -1.155000e+10
# Issuance Of Debt                                1.358900e+10  1.079000e+10
# Capital Expenditure                            -5.253500e+10 -3.225100e+10
# Income Tax Paid Supplemental Data                        NaN  1.916400e+10
# End Cash Position                               2.346600e+10  2.404800e+10
# Beginning Cash Position                         2.404800e+10  2.187900e+10
# Effect Of Exchange Rate Changes                -6.120000e+08 -4.210000e+08
# Changes In Cash                                 3.000000e+07  2.590000e+09
# Financing Cash Flow                            -7.973300e+10 -7.209300e+10
# ...

# %%
t.fast_info
# Out:
# lazy-loading dict with keys = ['currency', 'dayHigh', 'dayLow', 'exchange', 'fiftyDayAverage', 'lastPrice', 'lastVolume', 'marketCap', 'open', 'previousClose', 'quoteType', 'regularMarketPreviousClose', 'shares', 'tenDayAverageVolume', 'threeMonthAverageVolume', 'timezone', 'twoHundredDayAverage', 'yearChange', 'yearHigh', 'yearLow']

# %%
info = t.fast_info
info['timezone']
# Out:
# 'America/New_York'

# %%
t.news
# Out:
# [{'id': 'a20ff3b1-6a94-446e-9935-288333b726d0',
#   'content': {'id': 'a20ff3b1-6a94-446e-9935-288333b726d0',
#    'contentType': 'STORY',
#    'title': 'Stock market today: Dow, S&P 500, Nasdaq mixed with retail sales, inflation data in focus',
#    'description': '',
#    'summary': 'Markets are muted after a strong start to the week as investors take stock of a Fed-fueled rebound.',
#    'pubDate': '2025-11-25T14:36:04Z',
#    'displayTime': '2025-11-25T14:38:36Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-images/2019-12/441224f0-2925-11ea-96ff-875256a153fc',
#     'originalWidth': 5184,
#     'originalHeight': 3456,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/s5q0wy4rFCNaQwBbllMmUg--~B/aD0zNDU2O3c9NTE4NDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-images/2019-12/441224f0-2925-11ea-96ff-875256a153fc',
#       'width': 5184,
# ...
